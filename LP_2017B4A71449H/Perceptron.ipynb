# %%
import numpy as np
import pandas as pd


df2 = pd.read_csv('dataset_LP_2.csv')

# %%
df2.columns =  ['x1','x2','x3','y']

# %%
train_data2 = df2.sample(frac=0.7,random_state=0)
test_data2 = df2.drop(train_data2.index)
train_data2 =  train_data2.to_numpy()
test_data2 =  test_data2.to_numpy()

# %%
 def perceptron(data):
  w2=np.ones((4,1))
  miss_classified2=pd.DataFrame(columns=['x1','x2','x3','y'])
  eta=1
  i=0
  loss_previt2=0
  miss_cal = 0
  while i<1e6:
    loss=0
    for j in data:
      k=(np.matmul(np.transpose(w2),(np.array([1,j[0],j[1],j[2]])).reshape((4,1))))
      if j[3]==0:
        k=-1*k
      else:
        k=1*k
      if k<0:
        miss_classified2.loc[len(miss_classified2)]=j
        loss=loss-k
    miss=miss_classified2.to_numpy()
    miss_cal = len(miss)
    print('In the iteration',i)
    print('The number of misclassified examples are',len(miss))
    print('With a loss value of',loss)
    print('')
    if len(miss)==0:
          break
    if loss==loss_previt2:
          break
    if len(miss)==1:
          j=np.array(miss[0])
    else :
          j = np.array(miss[np.random.randint(0,len(miss)-1)])  
    tn=1
    if j[3]==0:
          tn=-1
    w2=w2 + (eta*tn)*((np.array([1,j[0],j[1],j[2]])).reshape((4,1)))
    i=i+1
    loss_previt2=loss
    miss_classified2=pd.DataFrame(columns=['x1','x2','x3','y'])
  return miss_cal,w2

def per_test(data,w2_train):
  miss_classified2=pd.DataFrame(columns=['x1','x2','x3','y'])
  eta=1
  i=0
  loss_previt2=0
  miss_cal = 0
  for j in data:
    k=(np.matmul(np.transpose(w2_train),(np.array([1,j[0],j[1],j[2]])).reshape((4,1))))
    if j[3]==0:
      k=-1*k
    else:
       k=1*k
    if k<0:
      miss_classified2.loc[len(miss_classified2)]=j
  miss=miss_classified2.to_numpy()
  miss_cal = len(miss)
  return miss_cal


miss_cal_train_2,w2_train = perceptron(train_data2)

miss_cal_test_2 = per_test(test_data2,w2_train)
print('Accuracy is',(1 - (miss_cal_test_2/len(test_data2)))*100,'%')
# Out:
# In the iteration 0
# The number of misclassified examples are 271
# With a loss value of [[662.64699989]]
#
# In the iteration 1
# The number of misclassified examples are 257
# With a loss value of [[949.92307477]]
#
# In the iteration 2
# The number of misclassified examples are 298
# With a loss value of [[5429.77297173]]
#
# In the iteration 3
# The number of misclassified examples are 277
# With a loss value of [[3279.01525802]]
#
# In the iteration 4
# The number of misclassified examples are 219
# With a loss value of [[1610.2291438]]
#
# In the iteration 5
# The number of misclassified examples are 129
# With a loss value of [[382.52022461]]
#
# In the iteration 6
# The number of misclassified examples are 18
# With a loss value of [[20.50806292]]
#
# In the iteration 7
# The number of misclassified examples are 100
# With a loss value of [[312.2558878]]
#
# In the iteration 8
# The number of misclassified examples are 63
# With a loss value of [[185.86326469]]
#
# In the iteration 9
# The number of misclassified examples are 114
# With a loss value of [[512.11897127]]
#
# In the iteration 10
# The number of misclassified examples are 18
# With a loss value of [[39.4812809]]
#
# In the iteration 11
# The number of misclassified examples are 137
# With a loss value of [[837.8218847]]
#
# In the iteration 12
# The number of misclassified examples are 17
# With a loss value of [[24.05940871]]
#
# In the iteration 13
# The number of misclassified examples are 127
# With a loss value of [[912.29238395]]
#
# In the iteration 14
# The number of misclassified examples are 71
# With a loss value of [[337.33996031]]
#
# In the iteration 15
# The number of misclassified examples are 27
# With a loss value of [[93.13793292]]
#
# In the iteration 16
# The number of misclassified examples are 67
# With a loss value of [[367.52047878]]
#
# In the iteration 17
# The number of misclassified examples are 0
# With a loss value of 0
#
# Accuracy is 99.66666666666667 %

# %%
df1 = pd.read_csv('dataset_LP_1.txt',sep=',', header=None)

# %%
df1.columns =  ['x1','x2','x3','x4','y']

# %%
train_data1 = df1.sample(frac=0.7,random_state=0)
test_data1 = df1.drop(train_data1.index)
train_data1 =  train_data1.to_numpy()
test_data1 =  test_data1.to_numpy()

# %%
def perceptron_1(data_1):  
  w1=np.ones((5,1))
  miss_classified1=pd.DataFrame(columns=['x1','x2','x3','x4','y'])
  eta=1
  i=0
  loss_previt1=0
  miss_calc_1 = 0
  while i<1e6:
    loss=0
    for j in data_1:
      k=(np.matmul(np.transpose(w1),(np.array([1,j[0],j[1],j[2],j[3]])).reshape((5,1))))
      if j[4]==0:
        k=-1*k
      else:
        k=1*k
      if k<0:
        miss_classified1.loc[len(miss_classified1)]=j
        loss=loss-k
    miss=miss_classified1.to_numpy()
    miss_calc_1 = len(miss)
    print('In the iteration',i)
    print('The number of misclassified examples are',len(miss))
    print('With a loss value of',loss[0][0])
    print('')
    if len(miss)==0:
          break
    if loss==loss_previt1:
          break
    if len(miss) < 6:
      break
    if len(miss)==1:
          j=np.array(miss[0])
    else :
          j = np.array(miss[np.random.randint(0,len(miss)-1)])  
    tn=1
    if j[4]==0:
          tn=-1
    w1=w1 + (eta*tn)*((np.array([1,j[0],j[1],j[2],j[3]])).reshape((5,1)))
    i=i+1
    loss_previt1=loss
    miss_classified1=pd.DataFrame(columns=['x1','x2','x3','x4','y'])
  return miss_calc_1,w1

miss_cal_train_1,w1_train = perceptron_1(train_data1)

def per_test_1(data_1,w1_train):  
  w1=np.ones((5,1))
  miss_classified1=pd.DataFrame(columns=['x1','x2','x3','x4','y'])
  eta=1
  i=0
  loss_previt1=0
  miss_calc_1 = 0
  for j in data_1:
    k=(np.matmul(np.transpose(w1_train),(np.array([1,j[0],j[1],j[2],j[3]])).reshape((5,1))))
    if j[4]==0:
      k=-1*k
    else:
      k=1*k
    if k<0:
      miss_classified1.loc[len(miss_classified1)]=j
  miss=miss_classified1.to_numpy()
  miss_calc_1 = len(miss)
  return miss_calc_1
    

miss_cal_test_1 = per_test_1(test_data1,w1_train)
print('Accuracy is ',(1 - (miss_cal_test_1/len(test_data1)))*100,'%')
# Out:
# Streaming output truncated to the last 5000 lines.
# The number of misclassified examples are 19
# With a loss value of 1028.8798996713724
#
# In the iteration 744
# The number of misclassified examples are 15
# With a loss value of 667.8728363563323
#
# In the iteration 745
# The number of misclassified examples are 15
# With a loss value of 163.8739641338709
#
# In the iteration 746
# The number of misclassified examples are 27
# With a loss value of 1284.1290039693506
#
# In the iteration 747
# The number of misclassified examples are 29
# With a loss value of 1881.2672979571707
#
# In the iteration 748
# The number of misclassified examples are 19
# With a loss value of 1127.7105349565543
#
# In the iteration 749
# The number of misclassified examples are 20
# With a loss value of 195.6154405720152
#
# In the iteration 750
# The number of misclassified examples are 16
# With a loss value of 698.8733192744322
#
# In the iteration 751
# The number of misclassified examples are 14
# With a loss value of 383.6905882070626
#
# In the iteration 752
# The number of misclassified examples are 19
# With a loss value of 512.311904780606
#
# In the iteration 753
# The number of misclassified examples are 15
# With a loss value of 613.0458539602815
#
# In the iteration 754
# The number of misclassified examples are 16
# With a loss value of 266.926752114956
#
# In the iteration 755
# The number of misclassified examples are 27
# With a loss value of 1556.9440694328125
#
# In the iteration 756
# The number of misclassified examples are 31
# With a loss value of 1908.5802581830912
#
# In the iteration 757
# The number of misclassified examples are 19
# With a loss value of 1069.5536616017023
#
# In the iteration 758
# The number of misclassified examples are 15
# With a loss value of 549.0333280734816
#
# In the iteration 759
# The number of misclassified examples are 14
# With a loss value of 246.89649736555347
#
# In the iteration 760
# The number of misclassified examples are 22
# With a loss value of 1329.0554836872743
#
# In the iteration 761
# The number of misclassified examples are 18
# With a loss value of 794.9178427348112
#
# In the iteration 762
# The number of misclassified examples are 14
# With a loss value of 252.1496467870527
#
# In the iteration 763
# The number of misclassified examples are 16
# With a loss value of 257.91519689006134
#
# In the iteration 764
# The number of misclassified examples are 42
# With a loss value of 2837.0531826308375
#
# In the iteration 765
# The number of misclassified examples are 14
# With a loss value of 521.8310733531436
#
# In the iteration 766
# The number of misclassified examples are 15
# With a loss value of 187.77589401560175
#
# In the iteration 767
# The number of misclassified examples are 26
# With a loss value of 1330.3526920824875
#
# In the iteration 768
# The number of misclassified examples are 18
# With a loss value of 799.5472532241929
#
# In the iteration 769
# The number of misclassified examples are 14
# With a loss value of 284.3262684589837
#
# In the iteration 770
# The number of misclassified examples are 21
# With a loss value of 286.82799739728324
#
# In the iteration 771
# The number of misclassified examples are 32
# With a loss value of 1720.127728338164
#
# In the iteration 772
# The number of misclassified examples are 23
# With a loss value of 1561.9294504881204
#
# In the iteration 773
# The number of misclassified examples are 15
# With a loss value of 443.43903301030315
#
# In the iteration 774
# The number of misclassified examples are 16
# With a loss value of 185.38234647073526
#
# In the iteration 775
# The number of misclassified examples are 39
# With a loss value of 3070.4673494708463
#
# In the iteration 776
# The number of misclassified examples are 36
# With a loss value of 2545.3351129324965
#
# In the iteration 777
# The number of misclassified examples are 23
# With a loss value of 1448.8415530382085
#
# In the iteration 778
# The number of misclassified examples are 20
# With a loss value of 1191.7193433799387
#
# In the iteration 779
# The number of misclassified examples are 15
# With a loss value of 558.6373129305432
#
# In the iteration 780
# The number of misclassified examples are 16
# With a loss value of 372.21126733246814
#
# In the iteration 781
# The number of misclassified examples are 36
# With a loss value of 2748.527693031518
#
# In the iteration 782
# The number of misclassified examples are 23
# With a loss value of 1655.2454345184078
#
# In the iteration 783
# The number of misclassified examples are 20
# With a loss value of 854.391998193026
#
# In the iteration 784
# The number of misclassified examples are 19
# With a loss value of 666.9913919162162
#
# In the iteration 785
# The number of misclassified examples are 30
# With a loss value of 1701.8206071591624
#
# In the iteration 786
# The number of misclassified examples are 23
# With a loss value of 797.0861027901024
#
# In the iteration 787
# The number of misclassified examples are 23
# With a loss value of 877.9639921592689
#
# In the iteration 788
# The number of misclassified examples are 27
# With a loss value of 1682.4872003701885
#
# In the iteration 789
# The number of misclassified examples are 23
# With a loss value of 885.2375950138207
#
# In the iteration 790
# The number of misclassified examples are 18
# With a loss value of 899.0942466533052
#
# In the iteration 791
# The number of misclassified examples are 25
# With a loss value of 1484.2091097732325
#
# In the iteration 792
# The number of misclassified examples are 15
# With a loss value of 420.2064211357289
#
# In the iteration 793
# The number of misclassified examples are 18
# With a loss value of 256.00618632607143
#
# In the iteration 794
# The number of misclassified examples are 31
# With a loss value of 1745.0141836060186
#
# In the iteration 795
# The number of misclassified examples are 15
# With a loss value of 279.94056394542764
#
# In the iteration 796
# The number of misclassified examples are 19
# With a loss value of 651.6727057896982
#
# In the iteration 797
# The number of misclassified examples are 33
# With a loss value of 2365.324276286366
#
# In the iteration 798
# The number of misclassified examples are 21
# With a loss value of 1266.5679630359489
#
# In the iteration 799
# The number of misclassified examples are 15
# With a loss value of 550.1369657083281
#
# In the iteration 800
# The number of misclassified examples are 14
# With a loss value of 191.02577188690861
#
# In the iteration 801
# The number of misclassified examples are 30
# With a loss value of 1320.335070102926
#
# In the iteration 802
# The number of misclassified examples are 24
# With a loss value of 1784.9697219306042
#
# In the iteration 803
# The number of misclassified examples are 21
# With a loss value of 1218.3138183108945
#
# In the iteration 804
# The number of misclassified examples are 16
# With a loss value of 571.5981420032278
#
# In the iteration 805
# The number of misclassified examples are 16
# With a loss value of 422.8751892695526
#
# In the iteration 806
# The number of misclassified examples are 18
# With a loss value of 829.290082850467
#
# In the iteration 807
# The number of misclassified examples are 15
# With a loss value of 427.33765574956783
#
# In the iteration 808
# The number of misclassified examples are 12
# With a loss value of 250.78172805323234
#
# In the iteration 809
# The number of misclassified examples are 38
# With a loss value of 2586.6476616717955
#
# In the iteration 810
# The number of misclassified examples are 21
# With a loss value of 1351.0571147885528
#
# In the iteration 811
# The number of misclassified examples are 19
# With a loss value of 909.1562995418384
#
# In the iteration 812
# The number of misclassified examples are 15
# With a loss value of 500.2388049275177
#
# In the iteration 813
# The number of misclassified examples are 16
# With a loss value of 247.85457324964642
#
# In the iteration 814
# The number of misclassified examples are 44
# With a loss value of 2708.7945140006227
#
# In the iteration 815
# The number of misclassified examples are 22
# With a loss value of 1436.7979617471935
#
# In the iteration 816
# The number of misclassified examples are 17
# With a loss value of 924.5914700023388
#
# In the iteration 817
# The number of misclassified examples are 22
# With a loss value of 627.7529505102505
#
# In the iteration 818
# The number of misclassified examples are 22
# With a loss value of 872.6206380165302
#
# In the iteration 819
# The number of misclassified examples are 39
# With a loss value of 2320.451511220505
#
# In the iteration 820
# The number of misclassified examples are 14
# With a loss value of 285.1151324823384
#
# In the iteration 821
# The number of misclassified examples are 19
# With a loss value of 671.0568818155401
#
# In the iteration 822
# The number of misclassified examples are 27
# With a loss value of 1741.7174347164746
#
# In the iteration 823
# The number of misclassified examples are 19
# With a loss value of 1251.95872017922
#
# In the iteration 824
# The number of misclassified examples are 17
# With a loss value of 825.0845394274684
#
# In the iteration 825
# The number of misclassified examples are 17
# With a loss value of 276.63755086173103
#
# In the iteration 826
# The number of misclassified examples are 23
# With a loss value of 856.6424702423714
#
# In the iteration 827
# The number of misclassified examples are 18
# With a loss value of 872.9908419904401
#
# In the iteration 828
# The number of misclassified examples are 14
# With a loss value of 479.56092714196933
#
# In the iteration 829
# The number of misclassified examples are 18
# With a loss value of 244.5136903175313
#
# In the iteration 830
# The number of misclassified examples are 18
# With a loss value of 929.6902830174778
#
# In the iteration 831
# The number of misclassified examples are 15
# With a loss value of 413.68808030988924
#
# In the iteration 832
# The number of misclassified examples are 12
# With a loss value of 178.94639115027434
#
# In the iteration 833
# The number of misclassified examples are 23
# With a loss value of 953.4250348343315
#
# In the iteration 834
# The number of misclassified examples are 32
# With a loss value of 2072.683697994894
#
# In the iteration 835
# The number of misclassified examples are 21
# With a loss value of 1256.6125426039594
#
# In the iteration 836
# The number of misclassified examples are 15
# With a loss value of 543.9698453755892
#
# In the iteration 837
# The number of misclassified examples are 15
# With a loss value of 244.17076027421814
#
# In the iteration 838
# The number of misclassified examples are 39
# With a loss value of 2342.326322724631
#
# In the iteration 839
# The number of misclassified examples are 14
# With a loss value of 498.3138710573493
#
# In the iteration 840
# The number of misclassified examples are 16
# With a loss value of 347.3958763855086
#
# In the iteration 841
# The number of misclassified examples are 15
# With a loss value of 590.6769442178689
#
# In the iteration 842
# The number of misclassified examples are 15
# With a loss value of 240.66336296970792
#
# In the iteration 843
# The number of misclassified examples are 17
# With a loss value of 434.6417771236177
#
# In the iteration 844
# The number of misclassified examples are 28
# With a loss value of 1860.943443241461
#
# In the iteration 845
# The number of misclassified examples are 21
# With a loss value of 1493.413771046019
#
# In the iteration 846
# The number of misclassified examples are 17
# With a loss value of 792.595523415719
#
# In the iteration 847
# The number of misclassified examples are 14
# With a loss value of 237.47126266398024
#
# In the iteration 848
# The number of misclassified examples are 18
# With a loss value of 322.71099814734157
#
# In the iteration 849
# The number of misclassified examples are 15
# With a loss value of 687.9067519277306
#
# In the iteration 850
# The number of misclassified examples are 13
# With a loss value of 244.1928592314597
#
# In the iteration 851
# The number of misclassified examples are 19
# With a loss value of 1021.2244167973034
#
# In the iteration 852
# The number of misclassified examples are 18
# With a loss value of 852.6672714441786
#
# In the iteration 853
# The number of misclassified examples are 15
# With a loss value of 282.246539762291
#
# In the iteration 854
# The number of misclassified examples are 20
# With a loss value of 1051.8797960743534
#
# In the iteration 855
# The number of misclassified examples are 18
# With a loss value of 925.6680981984498
#
# In the iteration 856
# The number of misclassified examples are 15
# With a loss value of 350.4690812634615
#
# In the iteration 857
# The number of misclassified examples are 15
# With a loss value of 228.67753998539087
#
# In the iteration 858
# The number of misclassified examples are 35
# With a loss value of 2428.0669116352324
#
# In the iteration 859
# The number of misclassified examples are 21
# With a loss value of 1412.489375819632
#
# In the iteration 860
# The number of misclassified examples are 16
# With a loss value of 726.5063251289108
#
# In the iteration 861
# The number of misclassified examples are 16
# With a loss value of 255.33006681475356
#
# In the iteration 862
# The number of misclassified examples are 24
# With a loss value of 543.0803293846301
#
# In the iteration 863
# The number of misclassified examples are 31
# With a loss value of 2149.2052164584534
#
# In the iteration 864
# The number of misclassified examples are 21
# With a loss value of 1269.809658591396
#
# In the iteration 865
# The number of misclassified examples are 17
# With a loss value of 636.3749685507922
#
# In the iteration 866
# The number of misclassified examples are 23
# With a loss value of 625.9234627511643
#
# In the iteration 867
# The number of misclassified examples are 16
# With a loss value of 830.6471769260095
#
# In the iteration 868
# The number of misclassified examples are 14
# With a loss value of 541.0887976592722
#
# In the iteration 869
# The number of misclassified examples are 10
# With a loss value of 182.99136379760532
#
# In the iteration 870
# The number of misclassified examples are 25
# With a loss value of 1238.657855083651
#
# In the iteration 871
# The number of misclassified examples are 15
# With a loss value of 227.20008496996448
#
# In the iteration 872
# The number of misclassified examples are 22
# With a loss value of 775.7470629354832
#
# In the iteration 873
# The number of misclassified examples are 19
# With a loss value of 1005.4051061243522
#
# In the iteration 874
# The number of misclassified examples are 15
# With a loss value of 425.1498899324325
#
# In the iteration 875
# The number of misclassified examples are 16
# With a loss value of 191.8970279780786
#
# In the iteration 876
# The number of misclassified examples are 21
# With a loss value of 1414.5237997304762
#
# In the iteration 877
# The number of misclassified examples are 15
# With a loss value of 637.1570989975235
#
# In the iteration 878
# The number of misclassified examples are 14
# With a loss value of 263.9237466336037
#
# In the iteration 879
# The number of misclassified examples are 13
# With a loss value of 300.90136919065515
#
# In the iteration 880
# The number of misclassified examples are 18
# With a loss value of 992.6770708949011
#
# In the iteration 881
# The number of misclassified examples are 14
# With a loss value of 352.10011943409364
#
# In the iteration 882
# The number of misclassified examples are 20
# With a loss value of 398.0069368564566
#
# In the iteration 883
# The number of misclassified examples are 15
# With a loss value of 352.86872025371343
#
# In the iteration 884
# The number of misclassified examples are 12
# With a loss value of 201.97798942852995
#
# In the iteration 885
# The number of misclassified examples are 38
# With a loss value of 2883.1265186523615
#
# In the iteration 886
# The number of misclassified examples are 28
# With a loss value of 1827.0616858433486
#
# In the iteration 887
# The number of misclassified examples are 20
# With a loss value of 1254.1664547957027
#
# In the iteration 888
# The number of misclassified examples are 16
# With a loss value of 603.1390959250424
#
# In the iteration 889
# The number of misclassified examples are 11
# With a loss value of 153.67838949439079
#
# In the iteration 890
# The number of misclassified examples are 22
# With a loss value of 766.4143098848816
#
# In the iteration 891
# The number of misclassified examples are 27
# With a loss value of 1873.5333698248355
#
# In the iteration 892
# The number of misclassified examples are 21
# With a loss value of 1362.3593467054873
#
# In the iteration 893
# The number of misclassified examples are 18
# With a loss value of 875.233131743961
#
# In the iteration 894
# The number of misclassified examples are 14
# With a loss value of 400.13566365345406
#
# In the iteration 895
# The number of misclassified examples are 21
# With a loss value of 345.15778092589824
#
# In the iteration 896
# The number of misclassified examples are 15
# With a loss value of 499.3988723257739
#
# In the iteration 897
# The number of misclassified examples are 11
# With a loss value of 210.41060825096184
#
# In the iteration 898
# The number of misclassified examples are 19
# With a loss value of 809.7032260356107
#
# In the iteration 899
# The number of misclassified examples are 32
# With a loss value of 2277.5158849506247
#
# In the iteration 900
# The number of misclassified examples are 20
# With a loss value of 1213.147462259582
#
# In the iteration 901
# The number of misclassified examples are 16
# With a loss value of 571.4889026387223
#
# In the iteration 902
# The number of misclassified examples are 12
# With a loss value of 159.99497998050148
#
# In the iteration 903
# The number of misclassified examples are 37
# With a loss value of 2055.4843299944196
#
# In the iteration 904
# The number of misclassified examples are 14
# With a loss value of 422.2421195230986
#
# In the iteration 905
# The number of misclassified examples are 14
# With a loss value of 173.7909065758503
#
# In the iteration 906
# The number of misclassified examples are 25
# With a loss value of 1380.3582096560274
#
# In the iteration 907
# The number of misclassified examples are 23
# With a loss value of 1695.5889332375825
#
# In the iteration 908
# The number of misclassified examples are 19
# With a loss value of 1216.9494097618679
#
# In the iteration 909
# The number of misclassified examples are 14
# With a loss value of 599.0044589769795
#
# In the iteration 910
# The number of misclassified examples are 14
# With a loss value of 244.94552247927965
#
# In the iteration 911
# The number of misclassified examples are 21
# With a loss value of 853.3511085078457
#
# In the iteration 912
# The number of misclassified examples are 17
# With a loss value of 851.9207867226573
#
# In the iteration 913
# The number of misclassified examples are 22
# With a loss value of 408.5941708014785
#
# In the iteration 914
# The number of misclassified examples are 17
# With a loss value of 422.47386418157885
#
# In the iteration 915
# The number of misclassified examples are 16
# With a loss value of 732.3407377346185
#
# In the iteration 916
# The number of misclassified examples are 15
# With a loss value of 202.61586382146018
#
# In the iteration 917
# The number of misclassified examples are 25
# With a loss value of 1201.5688321159123
#
# In the iteration 918
# The number of misclassified examples are 18
# With a loss value of 899.9363261244202
#
# In the iteration 919
# The number of misclassified examples are 14
# With a loss value of 334.4278060324012
#
# In the iteration 920
# The number of misclassified examples are 24
# With a loss value of 662.219963219474
#
# In the iteration 921
# The number of misclassified examples are 18
# With a loss value of 988.4793386028911
#
# In the iteration 922
# The number of misclassified examples are 15
# With a loss value of 574.1909304232908
#
# In the iteration 923
# The number of misclassified examples are 21
# With a loss value of 393.7551854848213
#
# In the iteration 924
# The number of misclassified examples are 23
# With a loss value of 1092.516895887158
#
# In the iteration 925
# The number of misclassified examples are 15
# With a loss value of 446.8320429966903
#
# In the iteration 926
# The number of misclassified examples are 11
# With a loss value of 174.16673674895858
#
# In the iteration 927
# The number of misclassified examples are 19
# With a loss value of 777.0564314069766
#
# In the iteration 928
# The number of misclassified examples are 16
# With a loss value of 243.41254658434931
#
# In the iteration 929
# The number of misclassified examples are 14
# With a loss value of 540.9863753926212
#
# In the iteration 930
# The number of misclassified examples are 42
# With a loss value of 3063.181634864945
#
# In the iteration 931
# The number of misclassified examples are 21
# With a loss value of 1111.7282164101669
#
# In the iteration 932
# The number of misclassified examples are 15
# With a loss value of 485.5031340984493
#
# In the iteration 933
# The number of misclassified examples are 12
# With a loss value of 312.0139186607625
#
# In the iteration 934
# The number of misclassified examples are 20
# With a loss value of 1187.4332861824914
#
# In the iteration 935
# The number of misclassified examples are 31
# With a loss value of 1999.3208602273307
#
# In the iteration 936
# The number of misclassified examples are 26
# With a loss value of 1605.2767052628863
#
# In the iteration 937
# The number of misclassified examples are 19
# With a loss value of 1038.5678960347464
#
# In the iteration 938
# The number of misclassified examples are 15
# With a loss value of 434.6491599531202
#
# In the iteration 939
# The number of misclassified examples are 13
# With a loss value of 303.19792111496156
#
# In the iteration 940
# The number of misclassified examples are 23
# With a loss value of 1281.144355930626
#
# In the iteration 941
# The number of misclassified examples are 28
# With a loss value of 1694.323641093052
#
# In the iteration 942
# The number of misclassified examples are 18
# With a loss value of 648.2393781200884
#
# In the iteration 943
# The number of misclassified examples are 15
# With a loss value of 265.1825062052513
#
# In the iteration 944
# The number of misclassified examples are 19
# With a loss value of 633.4807597401908
#
# In the iteration 945
# The number of misclassified examples are 30
# With a loss value of 2066.9352170373804
#
# In the iteration 946
# The number of misclassified examples are 20
# With a loss value of 1191.6242955141097
#
# In the iteration 947
# The number of misclassified examples are 18
# With a loss value of 805.5922062073696
#
# In the iteration 948
# The number of misclassified examples are 14
# With a loss value of 235.84734417176344
#
# In the iteration 949
# The number of misclassified examples are 23
# With a loss value of 855.943901075514
#
# In the iteration 950
# The number of misclassified examples are 17
# With a loss value of 841.4622955635405
#
# In the iteration 951
# The number of misclassified examples are 15
# With a loss value of 445.8637891664723
#
# In the iteration 952
# The number of misclassified examples are 15
# With a loss value of 299.67722816878427
#
# In the iteration 953
# The number of misclassified examples are 18
# With a loss value of 723.1590662852595
#
# In the iteration 954
# The number of misclassified examples are 11
# With a loss value of 234.06114569812385
#
# In the iteration 955
# The number of misclassified examples are 49
# With a loss value of 3553.315785841151
#
# In the iteration 956
# The number of misclassified examples are 32
# With a loss value of 2179.6040335395096
#
# In the iteration 957
# The number of misclassified examples are 19
# With a loss value of 1027.5463385788987
#
# In the iteration 958
# The number of misclassified examples are 16
# With a loss value of 404.4860488131215
#
# In the iteration 959
# The number of misclassified examples are 14
# With a loss value of 329.3995452866651
#
# In the iteration 960
# The number of misclassified examples are 35
# With a loss value of 2635.965698993472
#
# In the iteration 961
# The number of misclassified examples are 29
# With a loss value of 1528.043546160092
#
# In the iteration 962
# The number of misclassified examples are 12
# With a loss value of 352.38637699223244
#
# In the iteration 963
# The number of misclassified examples are 8
# With a loss value of 234.43840997537757
#
# In the iteration 964
# The number of misclassified examples are 32
# With a loss value of 1807.1343717111367
#
# In the iteration 965
# The number of misclassified examples are 18
# With a loss value of 734.9201821368106
#
# In the iteration 966
# The number of misclassified examples are 13
# With a loss value of 264.9509701755615
#
# In the iteration 967
# The number of misclassified examples are 18
# With a loss value of 748.8973908432112
#
# In the iteration 968
# The number of misclassified examples are 11
# With a loss value of 332.90525285476326
#
# In the iteration 969
# The number of misclassified examples are 21
# With a loss value of 550.8601963472329
#
# In the iteration 970
# The number of misclassified examples are 33
# With a loss value of 1801.4442289325502
#
# In the iteration 971
# The number of misclassified examples are 18
# With a loss value of 605.5114171975817
#
# In the iteration 972
# The number of misclassified examples are 10
# With a loss value of 243.24645418297547
#
# In the iteration 973
# The number of misclassified examples are 11
# With a loss value of 345.99701017925537
#
# In the iteration 974
# The number of misclassified examples are 33
# With a loss value of 2588.139943086821
#
# In the iteration 975
# The number of misclassified examples are 24
# With a loss value of 1535.158523320835
#
# In the iteration 976
# The number of misclassified examples are 22
# With a loss value of 1221.2208196874863
#
# In the iteration 977
# The number of misclassified examples are 18
# With a loss value of 749.1673194571613
#
# In the iteration 978
# The number of misclassified examples are 19
# With a loss value of 339.38800262756956
#
# In the iteration 979
# The number of misclassified examples are 17
# With a loss value of 495.78557720349437
#
# In the iteration 980
# The number of misclassified examples are 33
# With a loss value of 2450.497610893341
#
# In the iteration 981
# The number of misclassified examples are 23
# With a loss value of 1348.5474978308948
#
# In the iteration 982
# The number of misclassified examples are 18
# With a loss value of 718.5549153859861
#
# In the iteration 983
# The number of misclassified examples are 24
# With a loss value of 487.0842596219285
#
# In the iteration 984
# The number of misclassified examples are 25
# With a loss value of 1293.7228019761847
#
# In the iteration 985
# The number of misclassified examples are 20
# With a loss value of 993.8835171267996
#
# In the iteration 986
# The number of misclassified examples are 18
# With a loss value of 590.9825147178514
#
# In the iteration 987
# The number of misclassified examples are 15
# With a loss value of 176.44968887112972
#
# In the iteration 988
# The number of misclassified examples are 15
# With a loss value of 529.9808057469143
#
# In the iteration 989
# The number of misclassified examples are 15
# With a loss value of 240.27696796988573
#
# In the iteration 990
# The number of misclassified examples are 20
# With a loss value of 927.8691733145783
#
# In the iteration 991
# The number of misclassified examples are 31
# With a loss value of 2072.9633859153546
#
# In the iteration 992
# The number of misclassified examples are 26
# With a loss value of 1674.0191966876505
#
# In the iteration 993
# The number of misclassified examples are 18
# With a loss value of 882.4217370780725
#
# In the iteration 994
# The number of misclassified examples are 15
# With a loss value of 478.87813089368547
#
# In the iteration 995
# The number of misclassified examples are 11
# With a loss value of 193.5137910301539
#
# In the iteration 996
# The number of misclassified examples are 26
# With a loss value of 1517.0990290903342
#
# In the iteration 997
# The number of misclassified examples are 14
# With a loss value of 228.22112078259627
#
# In the iteration 998
# The number of misclassified examples are 22
# With a loss value of 803.2490063008024
#
# In the iteration 999
# The number of misclassified examples are 18
# With a loss value of 736.8771168032924
#
# In the iteration 1000
# The number of misclassified examples are 15
# With a loss value of 422.40978009123666
#
# In the iteration 1001
# The number of misclassified examples are 13
# With a loss value of 246.29080723339627
#
# In the iteration 1002
# The number of misclassified examples are 20
# With a loss value of 1170.4016169096358
#
# In the iteration 1003
# The number of misclassified examples are 15
# With a loss value of 491.2576878051773
#
# In the iteration 1004
# The number of misclassified examples are 13
# With a loss value of 200.31665011515395
#
# In the iteration 1005
# The number of misclassified examples are 21
# With a loss value of 648.6751845265566
#
# In the iteration 1006
# The number of misclassified examples are 29
# With a loss value of 1768.5881830639066
#
# In the iteration 1007
# The number of misclassified examples are 18
# With a loss value of 972.1547702007745
#
# In the iteration 1008
# The number of misclassified examples are 17
# With a loss value of 358.7960676532642
#
# In the iteration 1009
# The number of misclassified examples are 16
# With a loss value of 547.9256828712632
#
# In the iteration 1010
# The number of misclassified examples are 18
# With a loss value of 587.0389885843744
#
# In the iteration 1011
# The number of misclassified examples are 10
# With a loss value of 200.37646908876806
#
# In the iteration 1012
# The number of misclassified examples are 19
# With a loss value of 657.472641378816
#
# In the iteration 1013
# The number of misclassified examples are 49
# With a loss value of 3796.4362410704457
#
# In the iteration 1014
# The number of misclassified examples are 19
# With a loss value of 945.1409654324046
#
# In the iteration 1015
# The number of misclassified examples are 18
# With a loss value of 797.7546171049744
#
# In the iteration 1016
# The number of misclassified examples are 10
# With a loss value of 243.74150617342778
#
# In the iteration 1017
# The number of misclassified examples are 14
# With a loss value of 400.6317855000047
#
# In the iteration 1018
# The number of misclassified examples are 22
# With a loss value of 1167.2326105146155
#
# In the iteration 1019
# The number of misclassified examples are 17
# With a loss value of 580.4192614068958
#
# In the iteration 1020
# The number of misclassified examples are 13
# With a loss value of 172.16533560095382
#
# In the iteration 1021
# The number of misclassified examples are 23
# With a loss value of 782.1860225762834
#
# In the iteration 1022
# The number of misclassified examples are 55
# With a loss value of 4387.886192977495
#
# In the iteration 1023
# The number of misclassified examples are 15
# With a loss value of 249.12356856704343
#
# In the iteration 1024
# The number of misclassified examples are 20
# With a loss value of 594.3009230286374
#
# In the iteration 1025
# The number of misclassified examples are 14
# With a loss value of 307.15593072615843
#
# In the iteration 1026
# The number of misclassified examples are 18
# With a loss value of 655.2979108926991
#
# In the iteration 1027
# The number of misclassified examples are 27
# With a loss value of 1979.2346703495268
#
# In the iteration 1028
# The number of misclassified examples are 21
# With a loss value of 1386.156725012859
#
# In the iteration 1029
# The number of misclassified examples are 17
# With a loss value of 712.619226771795
#
# In the iteration 1030
# The number of misclassified examples are 14
# With a loss value of 383.3217661673079
#
# In the iteration 1031
# The number of misclassified examples are 16
# With a loss value of 205.76146864625292
#
# In the iteration 1032
# The number of misclassified examples are 15
# With a loss value of 542.5788315421265
#
# In the iteration 1033
# The number of misclassified examples are 12
# With a loss value of 163.50758989817527
#
# In the iteration 1034
# The number of misclassified examples are 36
# With a loss value of 2051.3760102996152
#
# In the iteration 1035
# The number of misclassified examples are 19
# With a loss value of 1264.312964497796
#
# In the iteration 1036
# The number of misclassified examples are 15
# With a loss value of 635.0265588151773
#
# In the iteration 1037
# The number of misclassified examples are 14
# With a loss value of 273.23974663075813
#
# In the iteration 1038
# The number of misclassified examples are 20
# With a loss value of 662.1675347928955
#
# In the iteration 1039
# The number of misclassified examples are 16
# With a loss value of 679.9950156798712
#
# In the iteration 1040
# The number of misclassified examples are 16
# With a loss value of 203.34093806604756
#
# In the iteration 1041
# The number of misclassified examples are 21
# With a loss value of 716.8129698198995
#
# In the iteration 1042
# The number of misclassified examples are 15
# With a loss value of 495.81995033422226
#
# In the iteration 1043
# The number of misclassified examples are 15
# With a loss value of 224.88467761715785
#
# In the iteration 1044
# The number of misclassified examples are 23
# With a loss value of 1206.5817102304413
#
# In the iteration 1045
# The number of misclassified examples are 12
# With a loss value of 240.05415459367032
#
# In the iteration 1046
# The number of misclassified examples are 39
# With a loss value of 3025.3514490446096
#
# In the iteration 1047
# The number of misclassified examples are 36
# With a loss value of 2593.383103297963
#
# In the iteration 1048
# The number of misclassified examples are 22
# With a loss value of 1593.3613011881087
#
# In the iteration 1049
# The number of misclassified examples are 18
# With a loss value of 883.0231475381083
#
# In the iteration 1050
# The number of misclassified examples are 14
# With a loss value of 342.30314617990274
#
# In the iteration 1051
# The number of misclassified examples are 16
# With a loss value of 637.8240939690379
#
# In the iteration 1052
# The number of misclassified examples are 46
# With a loss value of 3841.9055759160938
#
# In the iteration 1053
# The number of misclassified examples are 19
# With a loss value of 1061.0583434849568
#
# In the iteration 1054
# The number of misclassified examples are 22
# With a loss value of 1706.8464183327108
#
# In the iteration 1055
# The number of misclassified examples are 17
# With a loss value of 969.5076365489525
#
# In the iteration 1056
# The number of misclassified examples are 14
# With a loss value of 665.3056506892332
#
# In the iteration 1057
# The number of misclassified examples are 13
# With a loss value of 205.95072664391012
#
# In the iteration 1058
# The number of misclassified examples are 25
# With a loss value of 1369.4841011174374
#
# In the iteration 1059
# The number of misclassified examples are 15
# With a loss value of 626.2221313529428
#
# In the iteration 1060
# The number of misclassified examples are 14
# With a loss value of 270.9094853737238
#
# In the iteration 1061
# The number of misclassified examples are 29
# With a loss value of 977.34652627468
#
# In the iteration 1062
# The number of misclassified examples are 43
# With a loss value of 3053.6157083389785
#
# In the iteration 1063
# The number of misclassified examples are 14
# With a loss value of 274.95275948046867
#
# In the iteration 1064
# The number of misclassified examples are 28
# With a loss value of 1080.5117517835574
#
# In the iteration 1065
# The number of misclassified examples are 14
# With a loss value of 451.8255930022686
#
# In the iteration 1066
# The number of misclassified examples are 15
# With a loss value of 354.15155497887804
#
# In the iteration 1067
# The number of misclassified examples are 19
# With a loss value of 1115.0365580264465
#
# In the iteration 1068
# The number of misclassified examples are 15
# With a loss value of 678.4524086547777
#
# In the iteration 1069
# The number of misclassified examples are 15
# With a loss value of 188.18845056591823
#
# In the iteration 1070
# The number of misclassified examples are 20
# With a loss value of 432.44651667548305
#
# In the iteration 1071
# The number of misclassified examples are 27
# With a loss value of 2086.4036103577123
#
# In the iteration 1072
# The number of misclassified examples are 19
# With a loss value of 1362.8582827274258
#
# In the iteration 1073
# The number of misclassified examples are 15
# With a loss value of 728.4893891510077
#
# In the iteration 1074
# The number of misclassified examples are 14
# With a loss value of 370.9334782469886
#
# In the iteration 1075
# The number of misclassified examples are 25
# With a loss value of 463.87277447073626
#
# In the iteration 1076
# The number of misclassified examples are 15
# With a loss value of 588.3082409226078
#
# In the iteration 1077
# The number of misclassified examples are 13
# With a loss value of 228.98981159265816
#
# In the iteration 1078
# The number of misclassified examples are 20
# With a loss value of 1019.5788110329524
#
# In the iteration 1079
# The number of misclassified examples are 30
# With a loss value of 1992.9966110300638
#
# In the iteration 1080
# The number of misclassified examples are 20
# With a loss value of 1214.516094817364
#
# In the iteration 1081
# The number of misclassified examples are 15
# With a loss value of 579.8087774116074
#
# In the iteration 1082
# The number of misclassified examples are 12
# With a loss value of 174.82122815983774
#
# In the iteration 1083
# The number of misclassified examples are 32
# With a loss value of 1858.193911234278
#
# In the iteration 1084
# The number of misclassified examples are 22
# With a loss value of 1500.5590644945878
#
# In the iteration 1085
# The number of misclassified examples are 16
# With a loss value of 822.2009391510053
#
# In the iteration 1086
# The number of misclassified examples are 17
# With a loss value of 309.32015085083793
#
# In the iteration 1087
# The number of misclassified examples are 15
# With a loss value of 325.6511794641194
#
# In the iteration 1088
# The number of misclassified examples are 30
# With a loss value of 2275.5036084749468
#
# In the iteration 1089
# The number of misclassified examples are 18
# With a loss value of 1082.549869833187
#
# In the iteration 1090
# The number of misclassified examples are 14
# With a loss value of 722.4484699337688
#
# In the iteration 1091
# The number of misclassified examples are 14
# With a loss value of 368.38953343606863
#
# In the iteration 1092
# The number of misclassified examples are 25
# With a loss value of 770.05415298488
#
# In the iteration 1093
# The number of misclassified examples are 37
# With a loss value of 2453.027493281605
#
# In the iteration 1094
# The number of misclassified examples are 14
# With a loss value of 588.3568737832087
#
# In the iteration 1095
# The number of misclassified examples are 22
# With a loss value of 363.723176261311
#
# In the iteration 1096
# The number of misclassified examples are 16
# With a loss value of 466.3149522771468
#
# In the iteration 1097
# The number of misclassified examples are 14
# With a loss value of 460.5758277986396
#
# In the iteration 1098
# The number of misclassified examples are 16
# With a loss value of 303.8842936874395
#
# In the iteration 1099
# The number of misclassified examples are 15
# With a loss value of 678.9525114139584
#
# In the iteration 1100
# The number of misclassified examples are 12
# With a loss value of 237.39017892166984
#
# In the iteration 1101
# The number of misclassified examples are 26
# With a loss value of 1696.815563661876
#
# In the iteration 1102
# The number of misclassified examples are 20
# With a loss value of 1407.1710386504262
#
# In the iteration 1103
# The number of misclassified examples are 15
# With a loss value of 746.8967619457692
#
# In the iteration 1104
# The number of misclassified examples are 15
# With a loss value of 236.29511078831143
#
# In the iteration 1105
# The number of misclassified examples are 22
# With a loss value of 1173.3277478760308
#
# In the iteration 1106
# The number of misclassified examples are 15
# With a loss value of 407.46773659376976
#
# In the iteration 1107
# The number of misclassified examples are 16
# With a loss value of 369.8896100602767
#
# In the iteration 1108
# The number of misclassified examples are 38
# With a loss value of 2917.4471308565185
#
# In the iteration 1109
# The number of misclassified examples are 30
# With a loss value of 2082.9363041875617
#
# In the iteration 1110
# The number of misclassified examples are 19
# With a loss value of 1145.549956276308
#
# In the iteration 1111
# The number of misclassified examples are 15
# With a loss value of 794.6229511455707
#
# In the iteration 1112
# The number of misclassified examples are 15
# With a loss value of 417.0399243478702
#
# In the iteration 1113
# The number of misclassified examples are 21
# With a loss value of 655.8777471041476
#
# In the iteration 1114
# The number of misclassified examples are 18
# With a loss value of 1078.5033028056966
#
# In the iteration 1115
# The number of misclassified examples are 15
# With a loss value of 650.1272226663607
#
# In the iteration 1116
# The number of misclassified examples are 12
# With a loss value of 225.82438673802824
#
# In the iteration 1117
# The number of misclassified examples are 19
# With a loss value of 1020.0704645529522
#
# In the iteration 1118
# The number of misclassified examples are 22
# With a loss value of 1622.511220323955
#
# In the iteration 1119
# The number of misclassified examples are 19
# With a loss value of 1139.5578271379877
#
# In the iteration 1120
# The number of misclassified examples are 15
# With a loss value of 541.8371091089698
#
# In the iteration 1121
# The number of misclassified examples are 11
# With a loss value of 225.9471691785207
#
# In the iteration 1122
# The number of misclassified examples are 15
# With a loss value of 656.1530074294751
#
# In the iteration 1123
# The number of misclassified examples are 31
# With a loss value of 2073.024033457603
#
# In the iteration 1124
# The number of misclassified examples are 19
# With a loss value of 1090.9715561543865
#
# In the iteration 1125
# The number of misclassified examples are 14
# With a loss value of 499.37010867385044
#
# In the iteration 1126
# The number of misclassified examples are 13
# With a loss value of 186.359881654617
#
# In the iteration 1127
# The number of misclassified examples are 25
# With a loss value of 1222.6156394248594
#
# In the iteration 1128
# The number of misclassified examples are 15
# With a loss value of 356.0950631250692
#
# In the iteration 1129
# The number of misclassified examples are 13
# With a loss value of 379.1118390196717
#
# In the iteration 1130
# The number of misclassified examples are 23
# With a loss value of 1354.1449473449418
#
# In the iteration 1131
# The number of misclassified examples are 18
# With a loss value of 842.5064696084445
#
# In the iteration 1132
# The number of misclassified examples are 17
# With a loss value of 408.8405911628861
#
# In the iteration 1133
# The number of misclassified examples are 9
# With a loss value of 309.1803259043376
#
# In the iteration 1134
# The number of misclassified examples are 40
# With a loss value of 3134.9677060009094
#
# In the iteration 1135
# The number of misclassified examples are 31
# With a loss value of 1927.6194976119195
#
# In the iteration 1136
# The number of misclassified examples are 19
# With a loss value of 906.4718319472627
#
# In the iteration 1137
# The number of misclassified examples are 15
# With a loss value of 292.80604951898806
#
# In the iteration 1138
# The number of misclassified examples are 17
# With a loss value of 541.4277648598693
#
# In the iteration 1139
# The number of misclassified examples are 27
# With a loss value of 1805.5055666513113
#
# In the iteration 1140
# The number of misclassified examples are 17
# With a loss value of 894.5305262426548
#
# In the iteration 1141
# The number of misclassified examples are 15
# With a loss value of 580.0336575634689
#
# In the iteration 1142
# The number of misclassified examples are 14
# With a loss value of 225.33893680695044
#
# In the iteration 1143
# The number of misclassified examples are 21
# With a loss value of 865.6325063599876
#
# In the iteration 1144
# The number of misclassified examples are 16
# With a loss value of 715.4974556234071
#
# In the iteration 1145
# The number of misclassified examples are 15
# With a loss value of 241.2289006956262
#
# In the iteration 1146
# The number of misclassified examples are 20
# With a loss value of 348.53169849575
#
# In the iteration 1147
# The number of misclassified examples are 30
# With a loss value of 1528.8675178225512
#
# In the iteration 1148
# The number of misclassified examples are 11
# With a loss value of 180.61732767462286
#
# In the iteration 1149
# The number of misclassified examples are 26
# With a loss value of 1608.5859532009524
#
# In the iteration 1150
# The number of misclassified examples are 15
# With a loss value of 234.51196174683798
#
# In the iteration 1151
# The number of misclassified examples are 20
# With a loss value of 1080.599835634583
#
# In the iteration 1152
# The number of misclassified examples are 15
# With a loss value of 613.6758958034345
#
# In the iteration 1153
# The number of misclassified examples are 15
# With a loss value of 244.08354730547768
#
# In the iteration 1154
# The number of misclassified examples are 17
# With a loss value of 854.1616086883196
#
# In the iteration 1155
# The number of misclassified examples are 17
# With a loss value of 777.5224680655996
#
# In the iteration 1156
# The number of misclassified examples are 14
# With a loss value of 265.4356634096151
#
# In the iteration 1157
# The number of misclassified examples are 19
# With a loss value of 267.67516546679457
#
# In the iteration 1158
# The number of misclassified examples are 19
# With a loss value of 1069.8085406840887
#
# In the iteration 1159
# The number of misclassified examples are 14
# With a loss value of 485.42548211050405
#
# In the iteration 1160
# The number of misclassified examples are 16
# With a loss value of 251.9351682860808
#
# In the iteration 1161
# The number of misclassified examples are 25
# With a loss value of 1247.4295621890926
#
# In the iteration 1162
# The number of misclassified examples are 15
# With a loss value of 337.66193832682256
#
# In the iteration 1163
# The number of misclassified examples are 11
# With a loss value of 289.26865056865375
#
# In the iteration 1164
# The number of misclassified examples are 33
# With a loss value of 2599.212018664107
#
# In the iteration 1165
# The number of misclassified examples are 26
# With a loss value of 1550.0258993901034
#
# In the iteration 1166
# The number of misclassified examples are 18
# With a loss value of 741.8321577365068
#
# In the iteration 1167
# The number of misclassified examples are 10
# With a loss value of 221.0927304439586
#
# In the iteration 1168
# The number of misclassified examples are 22
# With a loss value of 1011.4799558779025
#
# In the iteration 1169
# The number of misclassified examples are 11
# With a loss value of 214.43986082405772
#
# In the iteration 1170
# The number of misclassified examples are 23
# With a loss value of 1339.0493015517357
#
# In the iteration 1171
# The number of misclassified examples are 21
# With a loss value of 1605.3415360021713
#
# In the iteration 1172
# The number of misclassified examples are 16
# With a loss value of 913.0273732265712
#
# In the iteration 1173
# The number of misclassified examples are 14
# With a loss value of 386.864831145605
#
# In the iteration 1174
# The number of misclassified examples are 12
# With a loss value of 195.37478358729317
#
# In the iteration 1175
# The number of misclassified examples are 18
# With a loss value of 776.824547246407
#
# In the iteration 1176
# The number of misclassified examples are 14
# With a loss value of 314.51799874150424
#
# In the iteration 1177
# The number of misclassified examples are 18
# With a loss value of 348.2860299341514
#
# In the iteration 1178
# The number of misclassified examples are 23
# With a loss value of 1503.8405887497552
#
# In the iteration 1179
# The number of misclassified examples are 21
# With a loss value of 1366.8628242851644
#
# In the iteration 1180
# The number of misclassified examples are 15
# With a loss value of 337.80123077940215
#
# In the iteration 1181
# The number of misclassified examples are 15
# With a loss value of 592.211060128705
#
# In the iteration 1182
# The number of misclassified examples are 19
# With a loss value of 1074.9348364230955
#
# In the iteration 1183
# The number of misclassified examples are 16
# With a loss value of 525.0120259533203
#
# In the iteration 1184
# The number of misclassified examples are 10
# With a loss value of 224.46444859750835
#
# In the iteration 1185
# The number of misclassified examples are 15
# With a loss value of 543.6402681367754
#
# In the iteration 1186
# The number of misclassified examples are 18
# With a loss value of 1004.3305089485455
#
# In the iteration 1187
# The number of misclassified examples are 18
# With a loss value of 566.3210677758454
#
# In the iteration 1188
# The number of misclassified examples are 10
# With a loss value of 205.66077836082056
#
# In the iteration 1189
# The number of misclassified examples are 22
# With a loss value of 1309.5785080512067
#
# In the iteration 1190
# The number of misclassified examples are 16
# With a loss value of 635.7217772238491
#
# In the iteration 1191
# The number of misclassified examples are 16
# With a loss value of 233.4095448301337
#
# In the iteration 1192
# The number of misclassified examples are 22
# With a loss value of 682.4409648889193
#
# In the iteration 1193
# The number of misclassified examples are 15
# With a loss value of 355.16850262170226
#
# In the iteration 1194
# The number of misclassified examples are 8
# With a loss value of 290.2936137038392
#
# In the iteration 1195
# The number of misclassified examples are 26
# With a loss value of 1746.9605315484346
#
# In the iteration 1196
# ...
#
# In the iteration 1843
# The number of misclassified examples are 15
# With a loss value of 443.7099933959058
#
# In the iteration 1844
# The number of misclassified examples are 9
# With a loss value of 278.4841180271467
#
# In the iteration 1845
# The number of misclassified examples are 32
# With a loss value of 2130.3069491919223
#
# In the iteration 1846
# The number of misclassified examples are 17
# With a loss value of 374.28613896371326
#
# In the iteration 1847
# The number of misclassified examples are 19
# With a loss value of 1258.1548462992187
#
# In the iteration 1848
# The number of misclassified examples are 15
# With a loss value of 623.6157117166748
#
# In the iteration 1849
# The number of misclassified examples are 14
# With a loss value of 331.4540550242959
#
# In the iteration 1850
# The number of misclassified examples are 15
# With a loss value of 646.551659664368
#
# In the iteration 1851
# The number of misclassified examples are 25
# With a loss value of 1778.271086189587
#
# In the iteration 1852
# The number of misclassified examples are 15
# With a loss value of 505.7328856627361
#
# In the iteration 1853
# The number of misclassified examples are 14
# With a loss value of 271.9751239762288
#
# In the iteration 1854
# The number of misclassified examples are 29
# With a loss value of 2374.723783643402
#
# In the iteration 1855
# The number of misclassified examples are 21
# With a loss value of 1494.845285812202
#
# In the iteration 1856
# The number of misclassified examples are 18
# With a loss value of 1074.0958985487975
#
# In the iteration 1857
# The number of misclassified examples are 15
# With a loss value of 558.8260273323854
#
# In the iteration 1858
# The number of misclassified examples are 12
# With a loss value of 201.44382032012322
#
# In the iteration 1859
# The number of misclassified examples are 27
# With a loss value of 2291.4271096403213
#
# In the iteration 1860
# The number of misclassified examples are 21
# With a loss value of 1759.8383752825478
#
# In the iteration 1861
# The number of misclassified examples are 18
# With a loss value of 1069.2517703941455
#
# In the iteration 1862
# The number of misclassified examples are 14
# With a loss value of 521.3670811047242
#
# In the iteration 1863
# The number of misclassified examples are 10
# With a loss value of 195.70653084732942
#
# In the iteration 1864
# The number of misclassified examples are 24
# With a loss value of 1309.7903676694386
#
# In the iteration 1865
# The number of misclassified examples are 20
# With a loss value of 1553.6928263215154
#
# In the iteration 1866
# The number of misclassified examples are 17
# With a loss value of 1078.6709114815962
#
# In the iteration 1867
# The number of misclassified examples are 20
# With a loss value of 304.57603469866535
#
# In the iteration 1868
# The number of misclassified examples are 20
# With a loss value of 537.1846302321977
#
# In the iteration 1869
# The number of misclassified examples are 23
# With a loss value of 1949.8498009119603
#
# In the iteration 1870
# The number of misclassified examples are 21
# With a loss value of 1419.6835446998184
#
# In the iteration 1871
# The number of misclassified examples are 19
# With a loss value of 1145.8280629744459
#
# In the iteration 1872
# The number of misclassified examples are 15
# With a loss value of 573.1884877605547
#
# In the iteration 1873
# The number of misclassified examples are 18
# With a loss value of 377.23738768503114
#
# In the iteration 1874
# The number of misclassified examples are 15
# With a loss value of 574.4375586425714
#
# In the iteration 1875
# The number of misclassified examples are 14
# With a loss value of 296.4875259775926
#
# In the iteration 1876
# The number of misclassified examples are 19
# With a loss value of 553.4700952924512
#
# In the iteration 1877
# The number of misclassified examples are 23
# With a loss value of 1852.3453955676578
#
# In the iteration 1878
# The number of misclassified examples are 17
# With a loss value of 1102.1941354019543
#
# In the iteration 1879
# The number of misclassified examples are 14
# With a loss value of 544.081672923893
#
# In the iteration 1880
# The number of misclassified examples are 17
# With a loss value of 319.3199636328051
#
# In the iteration 1881
# The number of misclassified examples are 26
# With a loss value of 845.4976888562747
#
# In the iteration 1882
# The number of misclassified examples are 33
# With a loss value of 2406.7234263370715
#
# In the iteration 1883
# The number of misclassified examples are 24
# With a loss value of 676.7158788942265
#
# In the iteration 1884
# The number of misclassified examples are 15
# With a loss value of 530.0271652706214
#
# In the iteration 1885
# The number of misclassified examples are 12
# With a loss value of 195.69739358614555
#
# In the iteration 1886
# The number of misclassified examples are 22
# With a loss value of 919.8906776695703
#
# In the iteration 1887
# The number of misclassified examples are 15
# With a loss value of 402.66827784402045
#
# In the iteration 1888
# The number of misclassified examples are 14
# With a loss value of 555.0915667933973
#
# In the iteration 1889
# The number of misclassified examples are 18
# With a loss value of 1075.5738928420205
#
# In the iteration 1890
# The number of misclassified examples are 15
# With a loss value of 475.6538681452095
#
# In the iteration 1891
# The number of misclassified examples are 11
# With a loss value of 259.56727613933714
#
# In the iteration 1892
# The number of misclassified examples are 17
# With a loss value of 477.77211674169644
#
# In the iteration 1893
# The number of misclassified examples are 18
# With a loss value of 1055.4055791830706
#
# In the iteration 1894
# The number of misclassified examples are 14
# With a loss value of 509.72539785625156
#
# In the iteration 1895
# The number of misclassified examples are 11
# With a loss value of 226.717830163798
#
# In the iteration 1896
# The number of misclassified examples are 12
# With a loss value of 601.9810206635759
#
# In the iteration 1897
# The number of misclassified examples are 21
# With a loss value of 1636.9673295041111
#
# In the iteration 1898
# The number of misclassified examples are 18
# With a loss value of 1156.7220050915603
#
# In the iteration 1899
# The number of misclassified examples are 15
# With a loss value of 563.00435962905
#
# In the iteration 1900
# The number of misclassified examples are 12
# With a loss value of 230.31071951095825
#
# In the iteration 1901
# The number of misclassified examples are 26
# With a loss value of 1445.2681470882949
#
# In the iteration 1902
# The number of misclassified examples are 18
# With a loss value of 1232.2539751030392
#
# In the iteration 1903
# The number of misclassified examples are 16
# With a loss value of 624.5416248302204
#
# In the iteration 1904
# The number of misclassified examples are 10
# With a loss value of 207.26546033673068
#
# In the iteration 1905
# The number of misclassified examples are 20
# With a loss value of 628.0330208096495
#
# In the iteration 1906
# The number of misclassified examples are 22
# With a loss value of 1830.057712020347
#
# In the iteration 1907
# The number of misclassified examples are 20
# With a loss value of 1532.9957255112788
#
# In the iteration 1908
# The number of misclassified examples are 17
# With a loss value of 876.6382879936696
#
# In the iteration 1909
# The number of misclassified examples are 15
# With a loss value of 537.4646623251175
#
# In the iteration 1910
# The number of misclassified examples are 10
# With a loss value of 232.74924280202043
#
# In the iteration 1911
# The number of misclassified examples are 19
# With a loss value of 421.55327300528074
#
# In the iteration 1912
# The number of misclassified examples are 17
# With a loss value of 558.330131157935
#
# In the iteration 1913
# The number of misclassified examples are 11
# With a loss value of 307.72731730192857
#
# In the iteration 1914
# The number of misclassified examples are 14
# With a loss value of 639.9271268600106
#
# In the iteration 1915
# The number of misclassified examples are 30
# With a loss value of 2265.751881520598
#
# In the iteration 1916
# The number of misclassified examples are 21
# With a loss value of 1410.710735802612
#
# In the iteration 1917
# The number of misclassified examples are 17
# With a loss value of 673.8867550077169
#
# In the iteration 1918
# The number of misclassified examples are 10
# With a loss value of 220.2106041493201
#
# In the iteration 1919
# The number of misclassified examples are 18
# With a loss value of 601.1072926104872
#
# In the iteration 1920
# The number of misclassified examples are 18
# With a loss value of 896.0198643015149
#
# In the iteration 1921
# The number of misclassified examples are 15
# With a loss value of 543.9101694301554
#
# In the iteration 1922
# The number of misclassified examples are 14
# With a loss value of 220.03404635286117
#
# In the iteration 1923
# The number of misclassified examples are 21
# With a loss value of 826.9015974758148
#
# In the iteration 1924
# The number of misclassified examples are 10
# With a loss value of 414.9799178424766
#
# In the iteration 1925
# The number of misclassified examples are 14
# With a loss value of 517.6813018213538
#
# In the iteration 1926
# The number of misclassified examples are 24
# With a loss value of 1431.5033924245342
#
# In the iteration 1927
# The number of misclassified examples are 21
# With a loss value of 1390.5952573250815
#
# In the iteration 1928
# The number of misclassified examples are 15
# With a loss value of 736.2615825979359
#
# In the iteration 1929
# The number of misclassified examples are 10
# With a loss value of 271.45327654134064
#
# In the iteration 1930
# The number of misclassified examples are 14
# With a loss value of 480.0246456153357
#
# In the iteration 1931
# The number of misclassified examples are 18
# With a loss value of 1075.0967337537643
#
# In the iteration 1932
# The number of misclassified examples are 15
# With a loss value of 466.13241505990544
#
# In the iteration 1933
# The number of misclassified examples are 6
# With a loss value of 266.83179082391274
#
# In the iteration 1934
# The number of misclassified examples are 20
# With a loss value of 1030.989295519697
#
# In the iteration 1935
# The number of misclassified examples are 18
# With a loss value of 734.4828735874534
#
# In the iteration 1936
# The number of misclassified examples are 13
# With a loss value of 263.9047970437641
#
# In the iteration 1937
# The number of misclassified examples are 20
# With a loss value of 519.5945415799333
#
# In the iteration 1938
# The number of misclassified examples are 35
# With a loss value of 2745.399246111083
#
# In the iteration 1939
# The number of misclassified examples are 18
# With a loss value of 1046.3543348218525
#
# In the iteration 1940
# The number of misclassified examples are 16
# With a loss value of 634.8840336146351
#
# In the iteration 1941
# The number of misclassified examples are 17
# With a loss value of 377.64183101527885
#
# In the iteration 1942
# The number of misclassified examples are 18
# With a loss value of 813.1147579372519
#
# In the iteration 1943
# The number of misclassified examples are 12
# With a loss value of 252.82087702857208
#
# In the iteration 1944
# The number of misclassified examples are 21
# With a loss value of 947.494792548652
#
# In the iteration 1945
# The number of misclassified examples are 16
# With a loss value of 796.3616133785246
#
# In the iteration 1946
# The number of misclassified examples are 20
# With a loss value of 444.5589979401247
#
# In the iteration 1947
# The number of misclassified examples are 21
# With a loss value of 674.2680037987623
#
# In the iteration 1948
# The number of misclassified examples are 14
# With a loss value of 393.5887300670758
#
# In the iteration 1949
# The number of misclassified examples are 20
# With a loss value of 381.847242039134
#
# In the iteration 1950
# The number of misclassified examples are 18
# With a loss value of 1049.3401148059115
#
# In the iteration 1951
# The number of misclassified examples are 16
# With a loss value of 701.0273012686436
#
# In the iteration 1952
# The number of misclassified examples are 15
# With a loss value of 285.8977064091677
#
# In the iteration 1953
# The number of misclassified examples are 18
# With a loss value of 976.8045151564602
#
# In the iteration 1954
# The number of misclassified examples are 15
# With a loss value of 638.9971075956329
#
# In the iteration 1955
# The number of misclassified examples are 11
# With a loss value of 243.92858885785893
#
# In the iteration 1956
# The number of misclassified examples are 18
# With a loss value of 667.9924035134436
#
# In the iteration 1957
# The number of misclassified examples are 11
# With a loss value of 316.7991482662479
#
# In the iteration 1958
# The number of misclassified examples are 13
# With a loss value of 531.0195054386354
#
# In the iteration 1959
# The number of misclassified examples are 19
# With a loss value of 1163.6924030158386
#
# In the iteration 1960
# The number of misclassified examples are 15
# With a loss value of 545.0380150854016
#
# In the iteration 1961
# The number of misclassified examples are 14
# With a loss value of 265.9206135789865
#
# In the iteration 1962
# The number of misclassified examples are 27
# With a loss value of 2242.5692644732444
#
# In the iteration 1963
# The number of misclassified examples are 20
# With a loss value of 1432.2096017809085
#
# In the iteration 1964
# The number of misclassified examples are 16
# With a loss value of 793.0818554281923
#
# In the iteration 1965
# The number of misclassified examples are 9
# With a loss value of 268.26217000611746
#
# In the iteration 1966
# The number of misclassified examples are 19
# With a loss value of 650.8192358278136
#
# In the iteration 1967
# The number of misclassified examples are 15
# With a loss value of 489.08088691300054
#
# In the iteration 1968
# The number of misclassified examples are 11
# With a loss value of 363.18409842707746
#
# In the iteration 1969
# The number of misclassified examples are 28
# With a loss value of 2291.6095259736708
#
# In the iteration 1970
# The number of misclassified examples are 20
# With a loss value of 1426.772400620485
#
# In the iteration 1971
# The number of misclassified examples are 18
# With a loss value of 976.9551689514476
#
# In the iteration 1972
# The number of misclassified examples are 16
# With a loss value of 544.0551565861309
#
# In the iteration 1973
# The number of misclassified examples are 11
# With a loss value of 293.7676469577569
#
# In the iteration 1974
# The number of misclassified examples are 14
# With a loss value of 579.2147761902603
#
# In the iteration 1975
# The number of misclassified examples are 33
# With a loss value of 2530.4838441369234
#
# In the iteration 1976
# The number of misclassified examples are 10
# With a loss value of 337.7743855107533
#
# In the iteration 1977
# The number of misclassified examples are 7
# With a loss value of 272.2492704273195
#
# In the iteration 1978
# The number of misclassified examples are 26
# With a loss value of 1678.9558159527614
#
# In the iteration 1979
# The number of misclassified examples are 16
# With a loss value of 605.9284556930404
#
# In the iteration 1980
# The number of misclassified examples are 13
# With a loss value of 225.8088024903749
#
# In the iteration 1981
# The number of misclassified examples are 18
# With a loss value of 663.3071591617844
#
# In the iteration 1982
# The number of misclassified examples are 22
# With a loss value of 1759.8023432101818
#
# In the iteration 1983
# The number of misclassified examples are 18
# With a loss value of 962.9199263663568
#
# In the iteration 1984
# The number of misclassified examples are 15
# With a loss value of 385.92007468280013
#
# In the iteration 1985
# The number of misclassified examples are 16
# With a loss value of 419.6040337906884
#
# In the iteration 1986
# The number of misclassified examples are 28
# With a loss value of 2136.0966088917517
#
# In the iteration 1987
# The number of misclassified examples are 23
# With a loss value of 1560.531686535883
#
# In the iteration 1988
# The number of misclassified examples are 19
# With a loss value of 879.8510435410333
#
# In the iteration 1989
# The number of misclassified examples are 14
# With a loss value of 422.5433360376288
#
# In the iteration 1990
# The number of misclassified examples are 13
# With a loss value of 492.93649230750157
#
# In the iteration 1991
# The number of misclassified examples are 18
# With a loss value of 656.5138066887547
#
# In the iteration 1992
# The number of misclassified examples are 5
# With a loss value of 226.1290361963254
#
# Accuracy is  99.51456310679612 %
